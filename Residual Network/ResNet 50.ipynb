# %%
import numpy as np
import matplotlib.pyplot as plt
import keras.utils as image
from skimage.io import imread
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions

# %%
model=ResNet50(weights='imagenet')

# %%
im='C:\\Users\\Vinay\\Downloads\\ball.jpg'

# %%
img=image.load_img(im,target_size=(224,224))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)
preds=model.predict(x)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
print('Predicted:',decode_predictions(preds,top=3)[0])
# Out:
# Predicted: [('n04254680', 'soccer_ball', 0.9996661), ('n03530642', 'honeycomb', 0.000331591), ('n04540053', 'volleyball', 1.1492485e-06)]

# %%
plt.imshow(imread(im))
print(decode_predictions(preds,top=1)[0][0][1])
# Out:
# soccer_ball
